# %% [markdown]
# ## CITS2402 - Introduction to Data Science - Project.
#
# ### Comparing Demographic Trends in Australian and New Zealand Census Data
#
# **Date:** August 2026.

# %% [markdown]
# ## Declaration
#
# This declaration should be completed and remain attached to the top of your submission.
#
# *we are aware of the University’s [policy on academic conduct](https://www.uwa.edu.au/policy/-/media/project/uwa/uwa/policy-library/policy/student-administration/academic-integrity/academic-integrity-policy.doc) and I declare that this assignment is entirely the work of the author(s) listed below and that suitable acknowledgement has been made for any sources of information used in preparing it. I have retained a copy for my own records.*
#
# - Name 1: Jai Singh Gurm
# - Student ID 1: 24714158
# - Name 2: Jerome Hu
# - Student ID 2: 23834247
# - Name 3: Shruti Bhatia
# - Student ID 3: 24984013
# - Date: 09/09/2026

# %% [markdown]
# The suffix `-template` should be replaced with the corresponding student numbers. For instance, if you are doing your assignment with another person, you should rename your file as `CITS2402-Assignment-STDNO1-STDNO2.ipynb`, where 'STDNO1' and 'STDNO2' are the corresponding student numbers involved in the submission.
#
# <hr>

# %%
# Your work starts here...
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
## Stage 1: Getting the Data 
## This is the stage where we load the datas from the model and convert it into a more readable set
# Out:
#   Cell In[1], line 2
#     *This is the stage where we load the datas from the model and convert it into a more readable set*
#           ^
# SyntaxError: invalid syntax

# %%
## Stage 2: Data Cleaning 
## Converting it into a more readable set

# %%
## Stage 3: Visualsation of data 
##
